# %% [markdown]
# # Export EditTagger to ONNX (Colab)
#
# 학습이 끝난 `best` 모델을 ONNX Runtime용으로 export합니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -q transformers optimum onnx onnxruntime

# %%
# !mkdir -p /content/work
# !cp /content/drive/MyDrive/grammarly_korean/export_edit_tagger_onnx.py /content/work/
# !ls -lah /content/work

# %%
INPUT_DIR = '/content/drive/MyDrive/grammarly_korean/checkpoints/edit_tagger_v1/best'
OUTPUT_DIR = '/content/drive/MyDrive/grammarly_korean/checkpoints/edit_tagger_v1_onnx'
INPUT_DIR, OUTPUT_DIR

# %%
# !python /content/work/export_edit_tagger_onnx.py \
  --input-dir "$INPUT_DIR" \
  --output-dir "$OUTPUT_DIR"

# %%
# !ls -lah "$OUTPUT_DIR"

# %% [markdown]
# 정상이라면 `model.onnx`, `config.json`, `tokenizer` 관련 파일들이 저장됩니다.
